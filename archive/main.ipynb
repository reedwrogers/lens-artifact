# %% [markdown]
# This code is based off a simple idea: dirty lens artifacts are really only noticeable in regions of the image where changes in intensity are common. In most of my photos in Greece, this translates to the blue sky or Aegean Sea. Thus, if we just apply a simple median filter to regions where most pixels are the same color, then we will vastly improve the images while not creating more artifacts (blur).

# %%
# this is running on my home server.. and I want to directly edit the images and replace them. Thus, I will grab an absolute path to the images:

import os
import cv2
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.patches as patches
import numpy as np

image_path = '/home/tars/Media/t9_mnt/Pictures/DCIM/100MSDCF'

test_filename = 'DSC01743.JPG'  # testing photo

test_filepath = os.path.join(image_path, test_filename)

if os.path.isfile(test_filepath):
    img_bgr = cv2.imread(test_filepath)
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title(test_filename)
    plt.show()
else:
    print(f"Image file '{test_filename}' not found in directory.")

# %%
# 1) figure out the exact regions of the image that display the lens artifacts.. save these regions in a csv

# Load the bounding box labels
labels = pd.read_csv("labels.csv")

# Display image and overlay bounding boxes
fig, ax = plt.subplots(1, figsize=(12, 8))
ax.imshow(img_rgb)

for _, row in labels.iterrows():
    rect = patches.Rectangle(
        (row['bbox_x'], row['bbox_y']),  # (x, y)
        row['bbox_width'],               # width
        row['bbox_height'],              # height
        linewidth=2,
        edgecolor='red',
        facecolor='none'
    )
    ax.add_patch(rect)
    ax.text(row['bbox_x'], row['bbox_y'] - 5, str(row['label_name']), color='white', fontsize=12,
            bbox=dict(facecolor='red', alpha=0.5))

plt.axis('off')
plt.tight_layout()
plt.show()

# %%
# 2) now, for each specific region, we should try a few different things.. start with a median filter

def clean_photo_median(image,kernel_size):

    img_filtered = image.copy()
        
    # Apply median filter to each region
    for _, row in labels.iterrows():
        x, y = int(row["bbox_x"]), int(row["bbox_y"])
        w, h = int(row["bbox_width"]), int(row["bbox_height"])
        
        # Extract region
        region = img_filtered[y:y+h, x:x+w]
    
        # Apply median filter to each channel
        filtered_region = np.zeros_like(region)
        for c in range(3):  # RGB channels
            filtered_region[..., c] = cv2.medianBlur(region[..., c], kernel_size)
    
        # Replace region in image
        img_filtered[y:y+h, x:x+w] = filtered_region

    return img_filtered


img = clean_photo_median(img_rgb,199)

# Display the result
plt.figure(figsize=(12, 8))
plt.imshow(img)
plt.axis('off')
plt.title(f'Median Filtered (Kernel {199}x{199}) Regions')
plt.show()

# %% [markdown]
# See how this leaves large patches of blurred artifacts?

# %%
def clean_photo_median_if_low_variance(image, labels, kernel_size=199, variance_threshold=20):
    img_filtered = image.copy()

    for _, row in labels.iterrows():
        x, y = int(row["bbox_x"]), int(row["bbox_y"])
        w, h = int(row["bbox_width"]), int(row["bbox_height"])
        
        region = img_filtered[y:y+h, x:x+w]

        # Compute per-channel variance, then mean across channels
        variance = np.var(region.astype(np.float32), axis=(0, 1)).mean()

        if variance < variance_threshold:
            # print(f"Applying filter at ({x},{y},{w},{h}) — variance={variance:.2f}")
            filtered_region = np.zeros_like(region)
            for c in range(3):
                filtered_region[..., c] = cv2.medianBlur(region[..., c], kernel_size)
            img_filtered[y:y+h, x:x+w] = filtered_region
        else:
            None
            # print(f"Skipping region at ({x},{y},{w},{h}) — variance={variance:.2f}")

    return img_filtered

# %%
img = clean_photo_median_if_low_variance(img_rgb, labels_filtered, kernel_size=199, variance_threshold=50)

plt.figure(figsize=(12, 8))
plt.imshow(img)
plt.axis('off')
plt.title('Filtered Low-Variance Regions Only')
plt.show()

# %% [markdown]
# Much better!

# %%
# 3) go from DSC01913.JPG to DSC01692.JPG - go in and apply the median filter, and save a copy as ".._edit.JPG"

image_path = '/home/tars/Media/t9_mnt/Pictures/DCIM/100MSDCF'

# Create the filename list
start_num = 1913 # had to stop and start because some images were vertical. Started at 1913 originally
end_num = 1692 - 1  # inclusive
for num in range(start_num, end_num, -1):
    filename = f"DSC0{num:04d}.JPG"
    full_path = os.path.join(image_path, filename)

    if not os.path.exists(full_path):
        print(f"Skipping missing file: {filename}")
        continue

    img_rgb = cv2.imread(full_path)
    if img_rgb is None:
        print(f"Could not read {filename}")
        continue
    img_rgb = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2RGB)

    # Apply median variance based filter
    filtered_img = clean_photo_median_if_low_variance(img_rgb, labels, kernel_size=199, variance_threshold=50)

    # Convert back to BGR for OpenCV savingthe
    filtered_bgr = cv2.cvtColor(filtered_img, cv2.COLOR_RGB2BGR)

    # Save with _edit.JPG
    save_name = filename.replace(".JPG", "_edit.JPG")
    save_path = os.path.join(image_path, save_name)
    cv2.imwrite(save_path, filtered_bgr)
    print(f"Saved {save_name}")
# Out:
# Saved DSC01913_edit.JPG
# Saved DSC01912_edit.JPG
# Saved DSC01911_edit.JPG
# Saved DSC01910_edit.JPG
# Saved DSC01909_edit.JPG
# Saved DSC01908_edit.JPG
# Saved DSC01907_edit.JPG
# Saved DSC01906_edit.JPG
# Saved DSC01905_edit.JPG
# Saved DSC01904_edit.JPG
# Saved DSC01903_edit.JPG
# Saved DSC01902_edit.JPG
# Saved DSC01901_edit.JPG
# Saved DSC01900_edit.JPG
# Saved DSC01899_edit.JPG
# Saved DSC01898_edit.JPG
# Saved DSC01897_edit.JPG
# Saved DSC01896_edit.JPG
# Saved DSC01895_edit.JPG
# Saved DSC01894_edit.JPG
# Saved DSC01893_edit.JPG
# Saved DSC01892_edit.JPG
# Saved DSC01891_edit.JPG
# Saved DSC01890_edit.JPG
# Saved DSC01889_edit.JPG
# Saved DSC01888_edit.JPG
# Saved DSC01887_edit.JPG
# Saved DSC01886_edit.JPG
# Saved DSC01885_edit.JPG
# Saved DSC01884_edit.JPG
# Saved DSC01883_edit.JPG
# Saved DSC01882_edit.JPG
# Saved DSC01881_edit.JPG
# Saved DSC01880_edit.JPG
# Saved DSC01879_edit.JPG
# Saved DSC01878_edit.JPG
# Saved DSC01877_edit.JPG
# Saved DSC01876_edit.JPG
# Saved DSC01875_edit.JPG
# Saved DSC01874_edit.JPG
# Saved DSC01873_edit.JPG
# Saved DSC01872_edit.JPG
# Saved DSC01871_edit.JPG
# Saved DSC01870_edit.JPG
# Saved DSC01869_edit.JPG
# Saved DSC01868_edit.JPG
# Saved DSC01867_edit.JPG
# Saved DSC01866_edit.JPG
# Saved DSC01865_edit.JPG
# Saved DSC01864_edit.JPG
# Saved DSC01863_edit.JPG
# Saved DSC01862_edit.JPG
# Saved DSC01861_edit.JPG
# Saved DSC01860_edit.JPG
# Saved DSC01859_edit.JPG
# Saved DSC01858_edit.JPG
# Saved DSC01857_edit.JPG
# Saved DSC01856_edit.JPG
# Saved DSC01855_edit.JPG
# Saved DSC01854_edit.JPG
# Saved DSC01853_edit.JPG
# Saved DSC01852_edit.JPG
# Saved DSC01851_edit.JPG
# Saved DSC01850_edit.JPG
# Saved DSC01849_edit.JPG
# Saved DSC01848_edit.JPG
# Saved DSC01847_edit.JPG
# Saved DSC01846_edit.JPG
# Saved DSC01845_edit.JPG
# Saved DSC01844_edit.JPG
# Saved DSC01843_edit.JPG
# Saved DSC01842_edit.JPG
# Saved DSC01841_edit.JPG
# Saved DSC01840_edit.JPG
# Saved DSC01839_edit.JPG
# Saved DSC01838_edit.JPG
# Saved DSC01837_edit.JPG
# Saved DSC01836_edit.JPG
# Saved DSC01835_edit.JPG
# Saved DSC01834_edit.JPG
# Saved DSC01833_edit.JPG
# Saved DSC01832_edit.JPG
# Saved DSC01831_edit.JPG
# Saved DSC01830_edit.JPG
# Saved DSC01829_edit.JPG
# Saved DSC01828_edit.JPG
# Saved DSC01827_edit.JPG
# /home/tars/jupyter/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:4268: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/tars/jupyter/lib/python3.12/site-packages/numpy/_core/_methods.py:181: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/tars/jupyter/lib/python3.12/site-packages/numpy/_core/_methods.py:212: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# Saved DSC01826_edit.JPG
# Saved DSC01825_edit.JPG
# Saved DSC01824_edit.JPG
# Saved DSC01823_edit.JPG
# Saved DSC01822_edit.JPG
# Saved DSC01821_edit.JPG
# Saved DSC01820_edit.JPG
# Saved DSC01819_edit.JPG
# Saved DSC01818_edit.JPG
# Saved DSC01817_edit.JPG
# Saved DSC01816_edit.JPG
# Saved DSC01815_edit.JPG
# Saved DSC01814_edit.JPG
# Saved DSC01813_edit.JPG
# Saved DSC01812_edit.JPG
# Saved DSC01811_edit.JPG
# Saved DSC01810_edit.JPG
# Saved DSC01809_edit.JPG
# Saved DSC01808_edit.JPG
# Saved DSC01807_edit.JPG
# Saved DSC01806_edit.JPG
# Saved DSC01805_edit.JPG
# Saved DSC01804_edit.JPG
# Saved DSC01803_edit.JPG
# Saved DSC01802_edit.JPG
# Saved DSC01801_edit.JPG
# Saved DSC01800_edit.JPG
# Saved DSC01799_edit.JPG
# Saved DSC01798_edit.JPG
# Saved DSC01797_edit.JPG
# Saved DSC01796_edit.JPG
# Saved DSC01795_edit.JPG
# Saved DSC01794_edit.JPG
# Saved DSC01793_edit.JPG
# Saved DSC01792_edit.JPG
# Saved DSC01791_edit.JPG
# Saved DSC01790_edit.JPG
# Saved DSC01789_edit.JPG
# Saved DSC01788_edit.JPG
# Saved DSC01787_edit.JPG
# Saved DSC01786_edit.JPG
# Saved DSC01785_edit.JPG
# Saved DSC01784_edit.JPG
# Saved DSC01783_edit.JPG
# Saved DSC01782_edit.JPG
# Saved DSC01781_edit.JPG
# Saved DSC01780_edit.JPG
# Saved DSC01779_edit.JPG
# Saved DSC01778_edit.JPG
# Saved DSC01777_edit.JPG
# Saved DSC01776_edit.JPG
# Saved DSC01775_edit.JPG
# Saved DSC01774_edit.JPG
# Saved DSC01773_edit.JPG
# Saved DSC01772_edit.JPG
# Saved DSC01771_edit.JPG
# Saved DSC01770_edit.JPG
# Saved DSC01769_edit.JPG
# Saved DSC01768_edit.JPG
# Saved DSC01767_edit.JPG
# Saved DSC01766_edit.JPG
# Saved DSC01765_edit.JPG
# Saved DSC01764_edit.JPG
# Saved DSC01763_edit.JPG
# Saved DSC01762_edit.JPG
# Saved DSC01761_edit.JPG
# Saved DSC01760_edit.JPG
# Saved DSC01759_edit.JPG
# Saved DSC01758_edit.JPG
# Saved DSC01757_edit.JPG
# Saved DSC01756_edit.JPG
# Saved DSC01755_edit.JPG
# Saved DSC01754_edit.JPG
# Saved DSC01753_edit.JPG
# Saved DSC01752_edit.JPG
# Saved DSC01751_edit.JPG
# Saved DSC01750_edit.JPG
# Saved DSC01749_edit.JPG
# Saved DSC01748_edit.JPG
# Saved DSC01747_edit.JPG
# Saved DSC01746_edit.JPG
# Saved DSC01745_edit.JPG
# Saved DSC01744_edit.JPG
# Saved DSC01743_edit.JPG
# Saved DSC01742_edit.JPG
# Saved DSC01741_edit.JPG
# Saved DSC01740_edit.JPG
# Saved DSC01739_edit.JPG
# Saved DSC01738_edit.JPG
# Saved DSC01737_edit.JPG
# Saved DSC01736_edit.JPG
# Saved DSC01735_edit.JPG
# Saved DSC01734_edit.JPG
# Saved DSC01733_edit.JPG
# Saved DSC01732_edit.JPG
# Saved DSC01731_edit.JPG
# Saved DSC01730_edit.JPG
# Saved DSC01729_edit.JPG
# Saved DSC01728_edit.JPG
# Saved DSC01727_edit.JPG
# Saved DSC01726_edit.JPG
# Saved DSC01725_edit.JPG
# Saved DSC01724_edit.JPG
# Saved DSC01723_edit.JPG
# Saved DSC01722_edit.JPG
# Saved DSC01721_edit.JPG
# Saved DSC01720_edit.JPG
# Saved DSC01719_edit.JPG
# Saved DSC01718_edit.JPG
# Saved DSC01717_edit.JPG
# Saved DSC01716_edit.JPG
# Saved DSC01715_edit.JPG
# Saved DSC01714_edit.JPG
# Saved DSC01713_edit.JPG
# Saved DSC01712_edit.JPG
# Saved DSC01711_edit.JPG
# Saved DSC01710_edit.JPG
# Saved DSC01709_edit.JPG
# Saved DSC01708_edit.JPG
# Saved DSC01707_edit.JPG
# Saved DSC01706_edit.JPG
# Saved DSC01705_edit.JPG
# Saved DSC01704_edit.JPG
# Saved DSC01703_edit.JPG
# Saved DSC01702_edit.JPG
# Saved DSC01701_edit.JPG
# Saved DSC01700_edit.JPG
# Saved DSC01699_edit.JPG
# Saved DSC01698_edit.JPG
# Saved DSC01697_edit.JPG
# Saved DSC01696_edit.JPG
# Saved DSC01695_edit.JPG
# Saved DSC01694_edit.JPG
# Saved DSC01693_edit.JPG
# Saved DSC01692_edit.JPG

# %%
# final step - copy the metadata of the non-edit photos to the edit photos. Thanks GPT!

import piexif
from PIL import Image

def copy_exif_to_edits(directory):
    for filename in os.listdir(directory):
        if filename.endswith('_edit.JPG'):
            edit_path = os.path.join(directory, filename)
            original_name = filename.replace('_edit', '')
            original_path = os.path.join(directory, original_name)

            if os.path.exists(original_path):
                try:
                    # Load EXIF from original
                    original_img = Image.open(original_path)
                    exif_dict = piexif.load(original_img.info.get("exif", b""))

                    # Load edited image
                    edit_img = Image.open(edit_path)

                    # Save edited image with original EXIF
                    exif_bytes = piexif.dump(exif_dict)
                    edit_img.save(edit_path, exif=exif_bytes)

                    print(f"Copied EXIF from {original_name} → {filename}")
                except Exception as e:
                    print(f"Failed on {filename}: {e}")
            else:
                print(f"No original found for {filename}")

copy_exif_to_edits('/home/tars/Media/t9_mnt/Pictures/DCIM/100MSDCF')
# Out:
# ✅ Copied EXIF from DSC01913.JPG → DSC01913_edit.JPG
# ✅ Copied EXIF from DSC01912.JPG → DSC01912_edit.JPG
# ✅ Copied EXIF from DSC01911.JPG → DSC01911_edit.JPG
# ✅ Copied EXIF from DSC01910.JPG → DSC01910_edit.JPG
# ✅ Copied EXIF from DSC01909.JPG → DSC01909_edit.JPG
# ✅ Copied EXIF from DSC01908.JPG → DSC01908_edit.JPG
# ✅ Copied EXIF from DSC01907.JPG → DSC01907_edit.JPG
# ✅ Copied EXIF from DSC01906.JPG → DSC01906_edit.JPG
# ✅ Copied EXIF from DSC01905.JPG → DSC01905_edit.JPG
# ✅ Copied EXIF from DSC01904.JPG → DSC01904_edit.JPG
# ✅ Copied EXIF from DSC01903.JPG → DSC01903_edit.JPG
# ✅ Copied EXIF from DSC01902.JPG → DSC01902_edit.JPG
# ✅ Copied EXIF from DSC01901.JPG → DSC01901_edit.JPG
# ✅ Copied EXIF from DSC01900.JPG → DSC01900_edit.JPG
# ✅ Copied EXIF from DSC01899.JPG → DSC01899_edit.JPG
# ✅ Copied EXIF from DSC01898.JPG → DSC01898_edit.JPG
# ✅ Copied EXIF from DSC01897.JPG → DSC01897_edit.JPG
# ✅ Copied EXIF from DSC01896.JPG → DSC01896_edit.JPG
# ✅ Copied EXIF from DSC01895.JPG → DSC01895_edit.JPG
# ✅ Copied EXIF from DSC01894.JPG → DSC01894_edit.JPG
# ✅ Copied EXIF from DSC01893.JPG → DSC01893_edit.JPG
# ✅ Copied EXIF from DSC01892.JPG → DSC01892_edit.JPG
# ✅ Copied EXIF from DSC01891.JPG → DSC01891_edit.JPG
# ✅ Copied EXIF from DSC01890.JPG → DSC01890_edit.JPG
# ✅ Copied EXIF from DSC01889.JPG → DSC01889_edit.JPG
# ✅ Copied EXIF from DSC01888.JPG → DSC01888_edit.JPG
# ✅ Copied EXIF from DSC01887.JPG → DSC01887_edit.JPG
# ✅ Copied EXIF from DSC01886.JPG → DSC01886_edit.JPG
# ✅ Copied EXIF from DSC01885.JPG → DSC01885_edit.JPG
# ✅ Copied EXIF from DSC01884.JPG → DSC01884_edit.JPG
# ✅ Copied EXIF from DSC01883.JPG → DSC01883_edit.JPG
# ✅ Copied EXIF from DSC01882.JPG → DSC01882_edit.JPG
# ✅ Copied EXIF from DSC01881.JPG → DSC01881_edit.JPG
# ✅ Copied EXIF from DSC01880.JPG → DSC01880_edit.JPG
# ✅ Copied EXIF from DSC01879.JPG → DSC01879_edit.JPG
# ✅ Copied EXIF from DSC01878.JPG → DSC01878_edit.JPG
# ✅ Copied EXIF from DSC01877.JPG → DSC01877_edit.JPG
# ✅ Copied EXIF from DSC01876.JPG → DSC01876_edit.JPG
# ✅ Copied EXIF from DSC01875.JPG → DSC01875_edit.JPG
# ✅ Copied EXIF from DSC01874.JPG → DSC01874_edit.JPG
# ✅ Copied EXIF from DSC01873.JPG → DSC01873_edit.JPG
# ✅ Copied EXIF from DSC01872.JPG → DSC01872_edit.JPG
# ✅ Copied EXIF from DSC01871.JPG → DSC01871_edit.JPG
# ✅ Copied EXIF from DSC01870.JPG → DSC01870_edit.JPG
# ✅ Copied EXIF from DSC01869.JPG → DSC01869_edit.JPG
# ✅ Copied EXIF from DSC01868.JPG → DSC01868_edit.JPG
# ✅ Copied EXIF from DSC01867.JPG → DSC01867_edit.JPG
# ✅ Copied EXIF from DSC01866.JPG → DSC01866_edit.JPG
# ✅ Copied EXIF from DSC01865.JPG → DSC01865_edit.JPG
# ✅ Copied EXIF from DSC01864.JPG → DSC01864_edit.JPG
# ✅ Copied EXIF from DSC01863.JPG → DSC01863_edit.JPG
# ✅ Copied EXIF from DSC01862.JPG → DSC01862_edit.JPG
# ✅ Copied EXIF from DSC01861.JPG → DSC01861_edit.JPG
# ✅ Copied EXIF from DSC01860.JPG → DSC01860_edit.JPG
# ✅ Copied EXIF from DSC01859.JPG → DSC01859_edit.JPG
# ✅ Copied EXIF from DSC01858.JPG → DSC01858_edit.JPG
# ✅ Copied EXIF from DSC01857.JPG → DSC01857_edit.JPG
# ✅ Copied EXIF from DSC01856.JPG → DSC01856_edit.JPG
# ✅ Copied EXIF from DSC01855.JPG → DSC01855_edit.JPG
# ✅ Copied EXIF from DSC01854.JPG → DSC01854_edit.JPG
# ✅ Copied EXIF from DSC01853.JPG → DSC01853_edit.JPG
# ✅ Copied EXIF from DSC01852.JPG → DSC01852_edit.JPG
# ✅ Copied EXIF from DSC01851.JPG → DSC01851_edit.JPG
# ✅ Copied EXIF from DSC01850.JPG → DSC01850_edit.JPG
# ✅ Copied EXIF from DSC01849.JPG → DSC01849_edit.JPG
# ✅ Copied EXIF from DSC01848.JPG → DSC01848_edit.JPG
# ✅ Copied EXIF from DSC01847.JPG → DSC01847_edit.JPG
# ✅ Copied EXIF from DSC01846.JPG → DSC01846_edit.JPG
# ✅ Copied EXIF from DSC01845.JPG → DSC01845_edit.JPG
# ✅ Copied EXIF from DSC01844.JPG → DSC01844_edit.JPG
# ✅ Copied EXIF from DSC01843.JPG → DSC01843_edit.JPG
# ✅ Copied EXIF from DSC01842.JPG → DSC01842_edit.JPG
# ✅ Copied EXIF from DSC01841.JPG → DSC01841_edit.JPG
# ✅ Copied EXIF from DSC01840.JPG → DSC01840_edit.JPG
# ✅ Copied EXIF from DSC01839.JPG → DSC01839_edit.JPG
# ✅ Copied EXIF from DSC01838.JPG → DSC01838_edit.JPG
# ✅ Copied EXIF from DSC01837.JPG → DSC01837_edit.JPG
# ✅ Copied EXIF from DSC01836.JPG → DSC01836_edit.JPG
# ✅ Copied EXIF from DSC01835.JPG → DSC01835_edit.JPG
# ✅ Copied EXIF from DSC01834.JPG → DSC01834_edit.JPG
# ✅ Copied EXIF from DSC01833.JPG → DSC01833_edit.JPG
# ✅ Copied EXIF from DSC01832.JPG → DSC01832_edit.JPG
# ✅ Copied EXIF from DSC01831.JPG → DSC01831_edit.JPG
# ✅ Copied EXIF from DSC01830.JPG → DSC01830_edit.JPG
# ✅ Copied EXIF from DSC01829.JPG → DSC01829_edit.JPG
# ✅ Copied EXIF from DSC01828.JPG → DSC01828_edit.JPG
# ✅ Copied EXIF from DSC01827.JPG → DSC01827_edit.JPG
# ✅ Copied EXIF from DSC01826.JPG → DSC01826_edit.JPG
# ✅ Copied EXIF from DSC01825.JPG → DSC01825_edit.JPG
# ✅ Copied EXIF from DSC01824.JPG → DSC01824_edit.JPG
# ✅ Copied EXIF from DSC01823.JPG → DSC01823_edit.JPG
# ✅ Copied EXIF from DSC01822.JPG → DSC01822_edit.JPG
# ✅ Copied EXIF from DSC01821.JPG → DSC01821_edit.JPG
# ✅ Copied EXIF from DSC01820.JPG → DSC01820_edit.JPG
# ✅ Copied EXIF from DSC01819.JPG → DSC01819_edit.JPG
# ✅ Copied EXIF from DSC01818.JPG → DSC01818_edit.JPG
# ✅ Copied EXIF from DSC01817.JPG → DSC01817_edit.JPG
# ✅ Copied EXIF from DSC01816.JPG → DSC01816_edit.JPG
# ✅ Copied EXIF from DSC01815.JPG → DSC01815_edit.JPG
# ✅ Copied EXIF from DSC01814.JPG → DSC01814_edit.JPG
# ✅ Copied EXIF from DSC01813.JPG → DSC01813_edit.JPG
# ✅ Copied EXIF from DSC01812.JPG → DSC01812_edit.JPG
# ✅ Copied EXIF from DSC01811.JPG → DSC01811_edit.JPG
# ✅ Copied EXIF from DSC01810.JPG → DSC01810_edit.JPG
# ✅ Copied EXIF from DSC01809.JPG → DSC01809_edit.JPG
# ✅ Copied EXIF from DSC01808.JPG → DSC01808_edit.JPG
# ✅ Copied EXIF from DSC01807.JPG → DSC01807_edit.JPG
# ✅ Copied EXIF from DSC01806.JPG → DSC01806_edit.JPG
# ✅ Copied EXIF from DSC01805.JPG → DSC01805_edit.JPG
# ✅ Copied EXIF from DSC01804.JPG → DSC01804_edit.JPG
# ✅ Copied EXIF from DSC01803.JPG → DSC01803_edit.JPG
# ✅ Copied EXIF from DSC01802.JPG → DSC01802_edit.JPG
# ✅ Copied EXIF from DSC01801.JPG → DSC01801_edit.JPG
# ✅ Copied EXIF from DSC01800.JPG → DSC01800_edit.JPG
# ✅ Copied EXIF from DSC01799.JPG → DSC01799_edit.JPG
# ✅ Copied EXIF from DSC01798.JPG → DSC01798_edit.JPG
# ✅ Copied EXIF from DSC01797.JPG → DSC01797_edit.JPG
# ✅ Copied EXIF from DSC01796.JPG → DSC01796_edit.JPG
# ✅ Copied EXIF from DSC01795.JPG → DSC01795_edit.JPG
# ✅ Copied EXIF from DSC01794.JPG → DSC01794_edit.JPG
# ✅ Copied EXIF from DSC01793.JPG → DSC01793_edit.JPG
# ✅ Copied EXIF from DSC01792.JPG → DSC01792_edit.JPG
# ✅ Copied EXIF from DSC01791.JPG → DSC01791_edit.JPG
# ✅ Copied EXIF from DSC01790.JPG → DSC01790_edit.JPG
# ✅ Copied EXIF from DSC01789.JPG → DSC01789_edit.JPG
# ✅ Copied EXIF from DSC01788.JPG → DSC01788_edit.JPG
# ✅ Copied EXIF from DSC01787.JPG → DSC01787_edit.JPG
# ✅ Copied EXIF from DSC01786.JPG → DSC01786_edit.JPG
# ✅ Copied EXIF from DSC01785.JPG → DSC01785_edit.JPG
# ✅ Copied EXIF from DSC01784.JPG → DSC01784_edit.JPG
# ✅ Copied EXIF from DSC01783.JPG → DSC01783_edit.JPG
# ✅ Copied EXIF from DSC01782.JPG → DSC01782_edit.JPG
# ✅ Copied EXIF from DSC01781.JPG → DSC01781_edit.JPG
# ✅ Copied EXIF from DSC01780.JPG → DSC01780_edit.JPG
# ✅ Copied EXIF from DSC01779.JPG → DSC01779_edit.JPG
# ✅ Copied EXIF from DSC01778.JPG → DSC01778_edit.JPG
# ✅ Copied EXIF from DSC01777.JPG → DSC01777_edit.JPG
# ✅ Copied EXIF from DSC01776.JPG → DSC01776_edit.JPG
# ✅ Copied EXIF from DSC01775.JPG → DSC01775_edit.JPG
# ✅ Copied EXIF from DSC01774.JPG → DSC01774_edit.JPG
# ✅ Copied EXIF from DSC01773.JPG → DSC01773_edit.JPG
# ✅ Copied EXIF from DSC01772.JPG → DSC01772_edit.JPG
# ✅ Copied EXIF from DSC01771.JPG → DSC01771_edit.JPG
# ✅ Copied EXIF from DSC01770.JPG → DSC01770_edit.JPG
# ✅ Copied EXIF from DSC01769.JPG → DSC01769_edit.JPG
# ✅ Copied EXIF from DSC01768.JPG → DSC01768_edit.JPG
# ✅ Copied EXIF from DSC01767.JPG → DSC01767_edit.JPG
# ✅ Copied EXIF from DSC01766.JPG → DSC01766_edit.JPG
# ✅ Copied EXIF from DSC01765.JPG → DSC01765_edit.JPG
# ✅ Copied EXIF from DSC01764.JPG → DSC01764_edit.JPG
# ✅ Copied EXIF from DSC01763.JPG → DSC01763_edit.JPG
# ✅ Copied EXIF from DSC01762.JPG → DSC01762_edit.JPG
# ✅ Copied EXIF from DSC01761.JPG → DSC01761_edit.JPG
# ✅ Copied EXIF from DSC01760.JPG → DSC01760_edit.JPG
# ✅ Copied EXIF from DSC01759.JPG → DSC01759_edit.JPG
# ✅ Copied EXIF from DSC01758.JPG → DSC01758_edit.JPG
# ✅ Copied EXIF from DSC01757.JPG → DSC01757_edit.JPG
# ✅ Copied EXIF from DSC01756.JPG → DSC01756_edit.JPG
# ✅ Copied EXIF from DSC01755.JPG → DSC01755_edit.JPG
# ✅ Copied EXIF from DSC01754.JPG → DSC01754_edit.JPG
# ✅ Copied EXIF from DSC01753.JPG → DSC01753_edit.JPG
# ✅ Copied EXIF from DSC01752.JPG → DSC01752_edit.JPG
# ✅ Copied EXIF from DSC01751.JPG → DSC01751_edit.JPG
# ✅ Copied EXIF from DSC01750.JPG → DSC01750_edit.JPG
# ✅ Copied EXIF from DSC01749.JPG → DSC01749_edit.JPG
# ✅ Copied EXIF from DSC01748.JPG → DSC01748_edit.JPG
# ✅ Copied EXIF from DSC01747.JPG → DSC01747_edit.JPG
# ✅ Copied EXIF from DSC01746.JPG → DSC01746_edit.JPG
# ✅ Copied EXIF from DSC01745.JPG → DSC01745_edit.JPG
# ✅ Copied EXIF from DSC01744.JPG → DSC01744_edit.JPG
# ✅ Copied EXIF from DSC01743.JPG → DSC01743_edit.JPG
# ✅ Copied EXIF from DSC01742.JPG → DSC01742_edit.JPG
# ✅ Copied EXIF from DSC01741.JPG → DSC01741_edit.JPG
# ✅ Copied EXIF from DSC01740.JPG → DSC01740_edit.JPG
# ✅ Copied EXIF from DSC01739.JPG → DSC01739_edit.JPG
# ✅ Copied EXIF from DSC01738.JPG → DSC01738_edit.JPG
# ✅ Copied EXIF from DSC01737.JPG → DSC01737_edit.JPG
# ✅ Copied EXIF from DSC01736.JPG → DSC01736_edit.JPG
# ✅ Copied EXIF from DSC01735.JPG → DSC01735_edit.JPG
# ✅ Copied EXIF from DSC01734.JPG → DSC01734_edit.JPG
# ✅ Copied EXIF from DSC01733.JPG → DSC01733_edit.JPG
# ✅ Copied EXIF from DSC01732.JPG → DSC01732_edit.JPG
# ✅ Copied EXIF from DSC01731.JPG → DSC01731_edit.JPG
# ✅ Copied EXIF from DSC01730.JPG → DSC01730_edit.JPG
# ✅ Copied EXIF from DSC01729.JPG → DSC01729_edit.JPG
# ✅ Copied EXIF from DSC01728.JPG → DSC01728_edit.JPG
# ✅ Copied EXIF from DSC01727.JPG → DSC01727_edit.JPG
# ✅ Copied EXIF from DSC01726.JPG → DSC01726_edit.JPG
# ✅ Copied EXIF from DSC01725.JPG → DSC01725_edit.JPG
# ✅ Copied EXIF from DSC01724.JPG → DSC01724_edit.JPG
# ✅ Copied EXIF from DSC01723.JPG → DSC01723_edit.JPG
# ✅ Copied EXIF from DSC01722.JPG → DSC01722_edit.JPG
# ✅ Copied EXIF from DSC01721.JPG → DSC01721_edit.JPG
# ✅ Copied EXIF from DSC01720.JPG → DSC01720_edit.JPG
# ✅ Copied EXIF from DSC01719.JPG → DSC01719_edit.JPG
# ✅ Copied EXIF from DSC01718.JPG → DSC01718_edit.JPG
# ✅ Copied EXIF from DSC01717.JPG → DSC01717_edit.JPG
# ✅ Copied EXIF from DSC01716.JPG → DSC01716_edit.JPG
# ✅ Copied EXIF from DSC01715.JPG → DSC01715_edit.JPG
# ✅ Copied EXIF from DSC01714.JPG → DSC01714_edit.JPG
# ✅ Copied EXIF from DSC01713.JPG → DSC01713_edit.JPG
# ✅ Copied EXIF from DSC01712.JPG → DSC01712_edit.JPG
# ✅ Copied EXIF from DSC01711.JPG → DSC01711_edit.JPG
# ✅ Copied EXIF from DSC01710.JPG → DSC01710_edit.JPG
# ✅ Copied EXIF from DSC01709.JPG → DSC01709_edit.JPG
# ✅ Copied EXIF from DSC01708.JPG → DSC01708_edit.JPG
# ✅ Copied EXIF from DSC01707.JPG → DSC01707_edit.JPG
# ✅ Copied EXIF from DSC01706.JPG → DSC01706_edit.JPG
# ✅ Copied EXIF from DSC01705.JPG → DSC01705_edit.JPG
# ✅ Copied EXIF from DSC01704.JPG → DSC01704_edit.JPG
# ✅ Copied EXIF from DSC01703.JPG → DSC01703_edit.JPG
# ✅ Copied EXIF from DSC01702.JPG → DSC01702_edit.JPG
# ✅ Copied EXIF from DSC01701.JPG → DSC01701_edit.JPG
# ✅ Copied EXIF from DSC01700.JPG → DSC01700_edit.JPG
# ✅ Copied EXIF from DSC01699.JPG → DSC01699_edit.JPG
# ✅ Copied EXIF from DSC01698.JPG → DSC01698_edit.JPG
# ✅ Copied EXIF from DSC01697.JPG → DSC01697_edit.JPG
# ✅ Copied EXIF from DSC01696.JPG → DSC01696_edit.JPG
# ✅ Copied EXIF from DSC01695.JPG → DSC01695_edit.JPG
# ✅ Copied EXIF from DSC01694.JPG → DSC01694_edit.JPG
# ✅ Copied EXIF from DSC01693.JPG → DSC01693_edit.JPG
# ✅ Copied EXIF from DSC01692.JPG → DSC01692_edit.JPG

# %% [markdown]
# Final thoughts: while this method is not perfect, and the outcome varies greatly on the type of photo taken (how far I was from the subject, how much sky is in the photo, etc) this worked well enough for now for the over 200 photos I took on the date where my lens was dirty.
